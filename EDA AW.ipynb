# %%
import pandas as pd
from pandas import plotting
import matplotlib
import seaborn as sns

# %%
cvd_df = pd.read_csv("CVD_cleaned.csv")
cvd_df
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 308849      Very Good     Within the past year      Yes            No
# 308850           Fair  Within the past 5 years      Yes            No
# 308851      Very Good      5 or more years ago      Yes            No
# 308852      Very Good     Within the past year      Yes            No
# 308853      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression  \
# 0               No           No         No
# ...

# %%
cvd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                308854 non-null  object
#  1   Checkup                       308854 non-null  object
#  2   Exercise                      308854 non-null  object
#  3   Heart_Disease                 308854 non-null  object
#  4   Skin_Cancer                   308854 non-null  object
#  5   Other_Cancer                  308854 non-null  object
#  6   Depression                    308854 non-null  object
#  7   Diabetes                      308854 non-null  object
#  8   Arthritis                     308854 non-null  object
#  9   Sex                           308854 non-null  object
#  10  Age_Category                  308854 non-null  object
#  11  Height_(cm)                   308854 non-null  float64
# ...

# %%
cvd_df.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Alcohol_Consumption  \
# count  308854.000000  308854.000000  308854.000000        308854.000000
# mean      170.615249      83.588655      28.626211             5.096366
# std        10.658026      21.343210       6.522323             8.199763
# min        91.000000      24.950000      12.020000             0.000000
# 25%       163.000000      68.040000      24.210000             0.000000
# 50%       170.000000      81.650000      27.440000             1.000000
# 75%       178.000000      95.250000      31.850000             6.000000
# max       241.000000     293.020000      99.330000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      308854.000000                 308854.000000
# mean           29.835200                     15.110441
# std            24.875735                     14.926238
# min             0.000000                      0.000000
# ...

# %%
cvd_df["Checkup"].hist()
# Out:
# <Axes: >

# %%
cvd_df.groupby("General_Health",sort=True).count()["Checkup"]
# Out:
# General_Health
# Excellent     55954
# Fair          35810
# Good          95364
# Poor          11331
# Very Good    110395
# Name: Checkup, dtype: int64

# %%
cvd_df.groupby("General_Health").count()["Checkup"].plot(kind="pie",colormap="BrBG")
# Out:
# <Axes: ylabel='Checkup'>

# %% [markdown]
# # Cancer

# %%
cvd_df[["Skin_Cancer","Smoking_History"]]
# Out:
#        Skin_Cancer Smoking_History
# 0               No             Yes
# 1               No              No
# 2               No              No
# 3               No              No
# 4               No             Yes
# ...            ...             ...
# 308849          No              No
# 308850          No              No
# 308851          No             Yes
# 308852          No              No
# 308853          No              No
#
# [308854 rows x 2 columns]

# %%
cvd_df[["Other_Cancer","Skin_Cancer","Smoking_History"]].value_counts()
# Out:
# Other_Cancer  Skin_Cancer  Smoking_History
# No            No           No                 155467
#                            Yes                100494
#               Yes          No                  12758
# Yes           No           No                  11768
#                            Yes                 11131
# No            Yes          Yes                 10257
# Yes           Yes          No                   3597
#                            Yes                  3382
# Name: count, dtype: int64

# %%
cvd_df[["Smoking_History"]].eq("Yes").sum()
# Out:
# Smoking_History    125264
# dtype: int64

# %%
cvd_df[["Other_Cancer","Skin_Cancer","Smoking_History"]].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Other_Cancer,Skin_Cancer,Smoking_History'>

# %%
cvd_df[["Other_Cancer","Skin_Cancer","Smoking_History"]].value_counts(normalize=True)
# Out:
# Other_Cancer  Skin_Cancer  Smoking_History
# No            No           No                 0.503367
#                            Yes                0.325377
#               Yes          No                 0.041308
# Yes           No           No                 0.038102
#                            Yes                0.036040
# No            Yes          Yes                0.033210
# Yes           Yes          No                 0.011646
#                            Yes                0.010950
# Name: proportion, dtype: float64

# %%
cvd_df.groupby(["Age_Category","Skin_Cancer"]).count()["Checkup"].plot(kind="bar", color=["c","r"],width=0.8,alpha=0.55)
# Out:
# <Axes: xlabel='Age_Category,Skin_Cancer'>

# %%
cvd_df.groupby(["Age_Category","Other_Cancer","Skin_Cancer"]).count()["Checkup"].plot(kind="bar", color=["c","r","r","r"],width=0.85,alpha=0.55)
# Out:
# <Axes: xlabel='Age_Category,Other_Cancer,Skin_Cancer'>

# %% [markdown]
# 83% av patienterna har inte cancer. 255961
#
# 52893 patienter har cancer,
# 24770 patienter har cancer samt röker,
# det motsvarar 8% av alla patienter,
# och 47% av alla cancer patienter,
#
# 125264 av alla patienter röker,
# ca 20% av alla patienter som röker har någon cancer

# %% [markdown]
# # Heart disease

# %%
cvd_df.groupby(["Age_Category","Heart_Disease"]).count()["General_Health"].plot(kind="bar", color=["c","r"],width=0.8,alpha=0.55)
# Out:
# <Axes: xlabel='Age_Category,Heart_Disease'>

# %%
cvd_df.groupby(["Age_Category","Heart_Disease"]).count()["Checkup"].plot(kind="bar", color=["c","r"],width=0.8,alpha=0.55)
# Out:
# <Axes: xlabel='Age_Category,Heart_Disease'>

# %%
cvd_df.plot.scatter(x="Heart_Disease",y="BMI",c="red")
# Out:
# <Axes: xlabel='Heart_Disease', ylabel='BMI'>

# %%
cvd_df[["Heart_Disease","BMI"]].value_counts()
# Out:
# Heart_Disease  BMI
# No             26.63    3137
#                27.46    2470
#                24.41    2420
#                27.44    2383
#                27.12    2059
#                         ...
# Yes            55.24       1
#                55.68       1
#                54.39       1
#                54.55       1
#                54.57       1
# Name: count, Length: 5682, dtype: int64

# %%
sns.violinplot(x = cvd_df["Heart_Disease"],y=cvd_df["BMI"])
# Out:
# <Axes: xlabel='Heart_Disease', ylabel='BMI'>

# %%
sns.heatmap(cvd_df.corr(numeric_only=True), cmap="Reds", annot=True)
# Out:
# <Axes: >

# %%
# Out:
# Heart_Disease
# No               283883
# Yes               24971
# Name: count, dtype: int64

# %%
sns.kdeplot(x = test,y=cvd_df["BMI"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 sns.kdeplot(x = test,y=cvd_df["BMI"])
#
# File c:\Users\serig\OneDrive\vikrigt\skola\ds23_projektkurs-main\git\.venv\Lib\site-packages\seaborn\distributions.py:1669, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1665 levels = kwargs.pop("n_levels", levels)
#    1667 # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
# -> 1669 p = _DistributionPlotter(
#    1670     data=data,
#    1671     variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1672 )
#    1674 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1676 if ax is None:
#
# ...

# %%
cvd_df[["Age_Category"]]
# Out:
#        Age_Category Other_Cancer
# 0             70-74           No
# 1             70-74           No
# 2             60-64           No
# 3             75-79           No
# 4               80+           No
# ...             ...          ...
# 308849        25-29           No
# 308850        65-69           No
# 308851        30-34           No
# 308852        65-69           No
# 308853        45-49           No
#
# [308854 rows x 2 columns]
